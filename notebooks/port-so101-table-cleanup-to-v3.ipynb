# %% [markdown]
# ## Converting Existing LeRobot Datasets from v2.1 to v3.0

# %%
# Pre-release build with v3 support:
# %pip install "https://github.com/huggingface/lerobot/archive/33cad37054c2b594ceba57463e8f11ee374fa93c.zip"
# Out:
# WARNING: Ignoring invalid distribution ~sspec (/usr/local/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~sspec (/usr/local/lib/python3.11/site-packages)
# Collecting https://github.com/huggingface/lerobot/archive/33cad37054c2b594ceba57463e8f11ee374fa93c.zip
#   Using cached https://github.com/huggingface/lerobot/archive/33cad37054c2b594ceba57463e8f11ee374fa93c.zip
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: datasets<=3.6.0,>=2.19.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.3.4) (3.6.0)
# Requirement already satisfied: diffusers>=0.27.2 in /usr/local/lib/python3.11/site-packages (from lerobot==0.3.4) (0.35.2)
# Requirement already satisfied: huggingface-hub>=0.34.2 in /usr/local/lib/python3.11/site-packages (from huggingface-hub[cli,hf-transfer]>=0.34.2->lerobot==0.3.4) (0.35.3)
# Requirement already satisfied: cmake>=3.29.0.1 in /usr/local/lib/python3.11/site-packages (from lerobot==0.3.4) (4.1.3)
# Requirement already satisfied: einops>=0.8.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.3.4) (0.8.2)
# Requirement already satisfied: opencv-python-headless>=4.9.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.3.4) (4.12.0.88)
# Requirement already satisfied: av>=14.2.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.3.4) (15.1.0)
# Requirement already satisfied: jsonlines>=4.0.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.3.4) (4.0.0)
# Requirement already satisfied: packaging>=24.2 in /usr/local/lib/python3.11/site-packages (from lerobot==0.3.4) (24.2)
# Requirement already satisfied: pynput>=1.7.7 in /usr/local/lib/python3.11/site-packages (from lerobot==0.3.4) (1.8.1)
# Requirement already satisfied: pyserial>=3.5 in /usr/local/lib/python3.11/site-packages (from lerobot==0.3.4) (3.5)
# Requirement already satisfied: wandb>=0.20.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.3.4) (0.24.2)
# Requirement already satisfied: torch<2.8.0,>=2.2.1 in /usr/local/lib/python3.11/site-packages (from lerobot==0.3.4) (2.7.1)
# Requirement already satisfied: torchcodec<0.6.0,>=0.2.1 in /usr/local/lib/python3.11/site-packages (from lerobot==0.3.4) (0.5)
# Requirement already satisfied: torchvision<0.23.0,>=0.21.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.3.4) (0.22.1)
# Requirement already satisfied: draccus==0.10.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.3.4) (0.10.0)
# Requirement already satisfied: gymnasium<1.0.0,>=0.29.1 in /usr/local/lib/python3.11/site-packages (from lerobot==0.3.4) (0.29.1)
# Requirement already satisfied: rerun-sdk<0.23.0,>=0.21.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.3.4) (0.22.1)
# Requirement already satisfied: deepdiff<9.0.0,>=7.0.1 in /usr/local/lib/python3.11/site-packages (from lerobot==0.3.4) (8.6.1)
# Requirement already satisfied: imageio<3.0.0,>=2.34.0 in /usr/local/lib/python3.11/site-packages (from imageio[ffmpeg]<3.0.0,>=2.34.0->lerobot==0.3.4) (2.37.2)
# Requirement already satisfied: termcolor<4.0.0,>=2.4.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.3.4) (3.3.0)
# Requirement already satisfied: mergedeep~=1.3 in /usr/local/lib/python3.11/site-packages (from draccus==0.10.0->lerobot==0.3.4) (1.3.4)
# Requirement already satisfied: pyyaml~=6.0 in /usr/local/lib/python3.11/site-packages (from draccus==0.10.0->lerobot==0.3.4) (6.0.3)
# Requirement already satisfied: pyyaml-include~=1.4 in /usr/local/lib/python3.11/site-packages (from draccus==0.10.0->lerobot==0.3.4) (1.4.1)
# Requirement already satisfied: toml~=0.10 in /usr/local/lib/python3.11/site-packages (from draccus==0.10.0->lerobot==0.3.4) (0.10.2)
# Requirement already satisfied: typing-inspect~=0.9.0 in /usr/local/lib/python3.11/site-packages (from draccus==0.10.0->lerobot==0.3.4) (0.9.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/site-packages (from datasets<=3.6.0,>=2.19.0->lerobot==0.3.4) (3.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/site-packages (from datasets<=3.6.0,>=2.19.0->lerobot==0.3.4) (2.2.6)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/site-packages (from datasets<=3.6.0,>=2.19.0->lerobot==0.3.4) (23.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/site-packages (from datasets<=3.6.0,>=2.19.0->lerobot==0.3.4) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/site-packages (from datasets<=3.6.0,>=2.19.0->lerobot==0.3.4) (3.0.0)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/site-packages (from datasets<=3.6.0,>=2.19.0->lerobot==0.3.4) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/site-packages (from datasets<=3.6.0,>=2.19.0->lerobot==0.3.4) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/site-packages (from datasets<=3.6.0,>=2.19.0->lerobot==0.3.4) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/site-packages (from datasets<=3.6.0,>=2.19.0->lerobot==0.3.4) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.11/site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=3.6.0,>=2.19.0->lerobot==0.3.4) (2025.3.0)
# Requirement already satisfied: orderly-set<6,>=5.4.1 in /usr/local/lib/python3.11/site-packages (from deepdiff<9.0.0,>=7.0.1->lerobot==0.3.4) (5.5.0)
# Requirement already satisfied: importlib_metadata in /usr/local/lib/python3.11/site-packages (from diffusers>=0.27.2->lerobot==0.3.4) (8.7.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/site-packages (from diffusers>=0.27.2->lerobot==0.3.4) (2026.1.15)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.11/site-packages (from diffusers>=0.27.2->lerobot==0.3.4) (0.7.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/site-packages (from diffusers>=0.27.2->lerobot==0.3.4) (12.1.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/site-packages (from gymnasium<1.0.0,>=0.29.1->lerobot==0.3.4) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/site-packages (from gymnasium<1.0.0,>=0.29.1->lerobot==0.3.4) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/site-packages (from gymnasium<1.0.0,>=0.29.1->lerobot==0.3.4) (0.0.4)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.11/site-packages (from huggingface-hub>=0.34.2->huggingface-hub[cli,hf-transfer]>=0.34.2->lerobot==0.3.4) (1.2.0)
# Requirement already satisfied: InquirerPy==0.3.4 in /usr/local/lib/python3.11/site-packages (from huggingface-hub[cli,hf-transfer]>=0.34.2->lerobot==0.3.4) (0.3.4)
# Requirement already satisfied: hf-transfer>=0.1.4 in /usr/local/lib/python3.11/site-packages (from huggingface-hub[cli,hf-transfer]>=0.34.2->lerobot==0.3.4) (0.1.9)
# Requirement already satisfied: pfzy<0.4.0,>=0.3.1 in /usr/local/lib/python3.11/site-packages (from InquirerPy==0.3.4->huggingface-hub[cli,hf-transfer]>=0.34.2->lerobot==0.3.4) (0.3.4)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.1 in /usr/local/lib/python3.11/site-packages (from InquirerPy==0.3.4->huggingface-hub[cli,hf-transfer]>=0.34.2->lerobot==0.3.4) (3.0.52)
# Requirement already satisfied: imageio-ffmpeg in /usr/local/lib/python3.11/site-packages (from imageio[ffmpeg]<3.0.0,>=2.34.0->lerobot==0.3.4) (0.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/site-packages (from imageio[ffmpeg]<3.0.0,>=2.34.0->lerobot==0.3.4) (7.2.2)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.11/site-packages (from jsonlines>=4.0.0->lerobot==0.3.4) (25.4.0)
# Requirement already satisfied: six in /usr/local/lib/python3.11/site-packages (from pynput>=1.7.7->lerobot==0.3.4) (1.17.0)
# Requirement already satisfied: evdev>=1.3 in /usr/local/lib/python3.11/site-packages (from pynput>=1.7.7->lerobot==0.3.4) (1.9.3)
# Requirement already satisfied: python-xlib>=0.17 in /usr/local/lib/python3.11/site-packages (from pynput>=1.7.7->lerobot==0.3.4) (0.33)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.3.4) (1.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.3.4) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.3.4) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.3.4) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.3.4) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.3.4) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.3.4) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.3.4) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.3.4) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.3.4) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.3.4) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.3.4) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.3.4) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.3.4) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.3.4) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.3.4) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.3.4) (1.11.1.6)
# Requirement already satisfied: triton==3.3.1 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.3.4) (3.3.1)
# Requirement already satisfied: setuptools>=40.8.0 in /usr/local/lib/python3.11/site-packages (from triton==3.3.1->torch<2.8.0,>=2.2.1->lerobot==0.3.4) (80.10.2)
# Requirement already satisfied: click>=8.0.1 in /usr/local/lib/python3.11/site-packages (from wandb>=0.20.0->lerobot==0.3.4) (8.3.1)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.11/site-packages (from wandb>=0.20.0->lerobot==0.3.4) (3.1.46)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/site-packages (from wandb>=0.20.0->lerobot==0.3.4) (4.3.6)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /usr/local/lib/python3.11/site-packages (from wandb>=0.20.0->lerobot==0.3.4) (6.33.5)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.11/site-packages (from wandb>=0.20.0->lerobot==0.3.4) (2.12.5)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.11/site-packages (from wandb>=0.20.0->lerobot==0.3.4) (2.52.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=3.6.0,>=2.19.0->lerobot==0.3.4) (3.13.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb>=0.20.0->lerobot==0.3.4) (4.0.12)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/site-packages (from pydantic<3->wandb>=0.20.0->lerobot==0.3.4) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /usr/local/lib/python3.11/site-packages (from pydantic<3->wandb>=0.20.0->lerobot==0.3.4) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.11/site-packages (from pydantic<3->wandb>=0.20.0->lerobot==0.3.4) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/site-packages (from requests>=2.32.2->datasets<=3.6.0,>=2.19.0->lerobot==0.3.4) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/site-packages (from requests>=2.32.2->datasets<=3.6.0,>=2.19.0->lerobot==0.3.4) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/site-packages (from requests>=2.32.2->datasets<=3.6.0,>=2.19.0->lerobot==0.3.4) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/site-packages (from requests>=2.32.2->datasets<=3.6.0,>=2.19.0->lerobot==0.3.4) (2026.1.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/site-packages (from sympy>=1.13.3->torch<2.8.0,>=2.2.1->lerobot==0.3.4) (1.3.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.11/site-packages (from typing-inspect~=0.9.0->draccus==0.10.0->lerobot==0.3.4) (1.1.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/site-packages (from importlib_metadata->diffusers>=0.27.2->lerobot==0.3.4) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/site-packages (from jinja2->torch<2.8.0,>=2.2.1->lerobot==0.3.4) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/site-packages (from pandas->datasets<=3.6.0,>=2.19.0->lerobot==0.3.4) (2.9.0.post0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=3.6.0,>=2.19.0->lerobot==0.3.4) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=3.6.0,>=2.19.0->lerobot==0.3.4) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=3.6.0,>=2.19.0->lerobot==0.3.4) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=3.6.0,>=2.19.0->lerobot==0.3.4) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=3.6.0,>=2.19.0->lerobot==0.3.4) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=3.6.0,>=2.19.0->lerobot==0.3.4) (1.22.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb>=0.20.0->lerobot==0.3.4) (5.0.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/site-packages (from prompt-toolkit<4.0.0,>=3.0.1->InquirerPy==0.3.4->huggingface-hub[cli,hf-transfer]>=0.34.2->lerobot==0.3.4) (0.6.0)
# WARNING: Ignoring invalid distribution ~sspec (/usr/local/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~sspec (/usr/local/lib/python3.11/site-packages)

# %%
# Step 1: Login to Hugging Face
import huggingface_hub
huggingface_hub.login(token="")

# %%
# Step 2: Download the dataset locally
from huggingface_hub import snapshot_download
from pathlib import Path

# Define local directory for the dataset
local_dataset_dir = Path("./datasets")
local_dataset_dir.mkdir(exist_ok=True)

# Download the v2.1 dataset
# TODO: Make repo_id the dataset repo id you want to convert
repo_id = "youliangtan/so101-table-cleanup"
local_path = snapshot_download(
    repo_id=repo_id,
    repo_type="dataset",
    revision="v2.1",  # Download the v2.1 version
    local_dir=local_dataset_dir / repo_id,
)

print(f"Dataset downloaded to: {local_path}")
# Out:
# Fetching 246 files:   0%|          | 0/246 [00:00<?, ?it/s]
# Dataset downloaded to: /content/datasets/youliangtan/so101-table-cleanup

# %%
# Step 3: Run the conversion script
# Using the convert_dataset function with the appropriate arguments

from lerobot.datasets.v30.convert_dataset_v21_to_v30 import convert_dataset

# Convert the dataset in place and push to hub
convert_dataset(
    repo_id=repo_id,
    branch=None,  # Use main branch
    data_file_size_in_mb=None,  # Use defaults (100 MB for data)
    video_file_size_in_mb=None,  # Use defaults (500 MB for videos)
    root=str(local_dataset_dir),  # Use the local directory where we downloaded
    push_to_hub=False,  # Push the converted dataset to hub
    force_conversion=False,  # Don't force if v3.0 already exists
)

print("Conversion complete!")
# Out:
# Using local dataset at datasets/youliangtan/so101-table-cleanup
# convert data files: 100%|██████████| 80/80 [00:00<00:00, 1997.09it/s]
# convert videos of observation.images.front: 100%|██████████| 80/80 [00:01<00:00, 50.45it/s]
# convert videos of observation.images.wrist: 100%|██████████| 80/80 [00:01<00:00, 46.44it/s]
# convert videos: 100%|██████████| 80/80 [00:00<00:00, 157310.98it/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Conversion complete!

# %%
# NOTE: Replace dillondesilva/so101-table-cleanup with the 
# repo id you want to push to. Ensure you have logged in
# to huggingface using the command:
# huggingface-cli login
# !huggingface-cli repo create dillondesilva/so101-table-cleanup --type dataset
# !huggingface-cli upload dillondesilva/so101-table-cleanup /content/datasets/youliangtan/so101-table-cleanup --repo-type dataset --revision v3.0
# Out:
# The --type argument is deprecated and will be removed in a future version. Use --repo-type instead.
# ⚠️  Warning: 'huggingface-cli repo' is deprecated. Use 'hf repo' instead.
# Successfully created dillondesilva/so101-table-cleanup on the Hub.
# Your repo is now available at https://huggingface.co/datasets/dillondesilva/so101-table-cleanup
# ⚠️  Warning: 'huggingface-cli upload' is deprecated. Use 'hf upload' instead.
# Branch 'v3.0' not found. Creating it...
# Start hashing 9 files.
# Finished hashing 9 files.
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#
#   ...hunk-000/file-000.parquet: 100% 90.1k/90.1k [00:00<?, ?B/s]
#
#
#   ...hunk-000/file-000.parquet: 100% 1.41M/1.41M [00:00<?, ?B/s]
#
#
#
#   ...leanup/meta/tasks.parquet: 100% 2.27k/2.27k [00:00<?, ?B/s]
#
#
#
#
#   ...st/chunk-000/file-001.mp4:  51% 16.8M/33.1M [00:00<?, ?B/s]
#
#
#
#
#
#   ...nt/chunk-000/file-000.mp4:   8% 16.7M/209M [00:00<?, ?B/s]
#
#
#
#
#
#
#   ...st/chunk-000/file-000.mp4:   4% 8.38M/208M [00:00<?, ?B/s]
#
#   ...hunk-000/file-000.parquet: 100% 90.1k/90.1k [00:00<?, ?B/s]
#
#
#   ...hunk-000/file-000.parquet: 100% 1.41M/1.41M [00:00<?, ?B/s]
#
#
#
#   ...leanup/meta/tasks.parquet: 100% 2.27k/2.27k [00:00<?, ?B/s]
#
#
#
#
#   ...st/chunk-000/file-001.mp4:  51% 16.8M/33.1M [00:00<?, ?B/s]
#
#
#
#
#
#   ...nt/chunk-000/file-000.mp4:   8% 16.7M/209M [00:00<?, ?B/s]
#
#
#
#
#
#
# Processing Files (3 / 6)      :   8% 43.4M/523M [00:00<00:04, 112MB/s,   ???B/s  ][A
#
#
#
#
#
#
#
#   ...nt/chunk-000/file-001.mp4:  12% 8.32M/71.6M [00:00<?, ?B/s]
#
#   ...hunk-000/file-000.parquet: 100% 90.1k/90.1k [00:00<?, ?B/s]
#
#
#   ...hunk-000/file-000.parquet: 100% 1.41M/1.41M [00:00<?, ?B/s]
#
#
#
#   ...leanup/meta/tasks.parquet: 100% 2.27k/2.27k [00:00<?, ?B/s]
#
#
#
#
#   ...st/chunk-000/file-001.mp4:  51% 16.8M/33.1M [00:00<?, ?B/s]
#
#
#
#
#
#   ...nt/chunk-000/file-000.mp4:   8% 16.7M/209M [00:00<?, ?B/s]
#
#
#
#
#
#
#   ...st/chunk-000/file-000.mp4:   4% 8.38M/208M [00:00<?, ?B/s]
#
#
#
#
#
#
#
#   ...nt/chunk-000/file-001.mp4:  12% 8.32M/71.6M [00:00<?, ?B/s]
#
#   ...hunk-000/file-000.parquet: 100% 90.1k/90.1k [00:00<?, ?B/s]
#
#
#   ...hunk-000/file-000.parquet: 100% 1.41M/1.41M [00:00<?, ?B/s]
#
#
#
#   ...leanup/meta/tasks.parquet: 100% 2.27k/2.27k [00:00<?, ?B/s]
#
#
#
#
#   ...st/chunk-000/file-001.mp4:  51% 16.8M/33.1M [00:00<?, ?B/s]
#
#
#
#
#
#   ...nt/chunk-000/file-000.mp4:   8% 16.7M/209M [00:00<?, ?B/s]
#
#
#
#
#
#
#   ...st/chunk-000/file-000.mp4:  12% 25.2M/208M [00:00<00:02, 74.6MB/s]
#
#
#
#
#
#
#
# Processing Files (3 / 7)      :  15% 76.9M/523M [00:00<00:03, 130MB/s,  143MB/s  ][A
#
#   ...hunk-000/file-000.parquet: 100% 90.1k/90.1k [00:00<?, ?B/s]
#
#
#   ...hunk-000/file-000.parquet: 100% 1.41M/1.41M [00:00<?, ?B/s]
#
#
#
#   ...leanup/meta/tasks.parquet: 100% 2.27k/2.27k [00:00<?, ?B/s]
#
#
#
#
#   ...st/chunk-000/file-001.mp4: 100% 33.1M/33.1M [00:00<00:00, 38.4MB/s]
#
#
#
#
#
#   ...nt/chunk-000/file-000.mp4:  12% 25.1M/209M [00:00<00:09, 19.8MB/s]
#
#
#
#
#
#
#   ...st/chunk-000/file-000.mp4:  12% 25.2M/208M [00:00<00:04, 39.8MB/s]
#
#
#
#
#
#
#
# Processing Files (4 / 7)      :  21% 110M/523M [00:00<00:02, 143MB/s,  155MB/s  ] [A
#
#   ...hunk-000/file-000.parquet: 100% 90.1k/90.1k [00:00<?, ?B/s]
#
#
#   ...hunk-000/file-000.parquet: 100% 1.41M/1.41M [00:00<?, ?B/s]
#
#
#
#   ...leanup/meta/tasks.parquet: 100% 2.27k/2.27k [00:00<?, ?B/s]
#
#
#
#
#   ...st/chunk-000/file-001.mp4: 100% 33.1M/33.1M [00:00<00:00, 26.1MB/s]
#
#
#
#
#
#   ...nt/chunk-000/file-000.mp4:  16% 33.4M/209M [00:00<00:06, 26.7MB/s]
#
#
#
#
#
#
#   ...st/chunk-000/file-000.mp4:  20% 41.9M/208M [00:00<00:03, 53.8MB/s]
#
#
#
#
#
#
#
# Processing Files (4 / 7)      :  27% 143M/523M [00:01<00:02, 151MB/s,  159MB/s  ]
#
#   ...hunk-000/file-000.parquet: 100% 90.1k/90.1k [00:00<?, ?B/s]
#
#
#   ...hunk-000/file-000.parquet: 100% 1.41M/1.41M [00:00<?, ?B/s]
#
#
#
#   ...leanup/meta/tasks.parquet: 100% 2.27k/2.27k [00:00<?, ?B/s]
#
#
#
#
#   ...st/chunk-000/file-001.mp4: 100% 33.1M/33.1M [00:00<00:00, 19.7MB/s]
#
#
#
#
#
#   ...nt/chunk-000/file-000.mp4:  20% 41.9M/209M [00:00<00:05, 30.5MB/s]
#
#
#
#
#
#
#   ...st/chunk-000/file-000.mp4:  24% 50.3M/208M [00:00<00:03, 50.9MB/s]
#
#
#
#
#
#
#
# Processing Files (4 / 7)      :  32% 169M/523M [00:01<00:02, 143MB/s,  151MB/s  ]
#
#   ...hunk-000/file-000.parquet: 100% 90.1k/90.1k [00:01<?, ?B/s]
#
#
#   ...hunk-000/file-000.parquet: 100% 1.41M/1.41M [00:01<?, ?B/s]
#
#
#
#   ...leanup/meta/tasks.parquet: 100% 2.27k/2.27k [00:01<?, ?B/s]
#
#
#
#
#   ...st/chunk-000/file-001.mp4: 100% 33.1M/33.1M [00:01<00:00, 15.8MB/s]
#
#
#
#
#
#   ...nt/chunk-000/file-000.mp4:  24% 50.2M/209M [00:01<00:04, 32.5MB/s]
#
#
#
#
#
#
#   ...st/chunk-000/file-000.mp4:  28% 58.7M/208M [00:01<00:03, 49.0MB/s]
#
#
#
#
#
#
#
# Processing Files (4 / 7)      :  37% 194M/523M [00:01<00:02, 137MB/s,  146MB/s  ]
#
#   ...hunk-000/file-000.parquet: 100% 90.1k/90.1k [00:01<?, ?B/s]
#
#
#   ...hunk-000/file-000.parquet: 100% 1.41M/1.41M [00:01<?, ?B/s]
#
#
#
#   ...leanup/meta/tasks.parquet: 100% 2.27k/2.27k [00:01<?, ?B/s]
#
#
#
#
#   ...st/chunk-000/file-001.mp4: 100% 33.1M/33.1M [00:01<00:00, 13.3MB/s]
#
#
#
#
#
#   ...nt/chunk-000/file-000.mp4:  28% 58.6M/209M [00:01<00:04, 34.2MB/s]
#
#
#
#
#
#
#   ...st/chunk-000/file-000.mp4:  36% 75.4M/208M [00:01<00:02, 54.8MB/s]
#
#
#
#
#
#
#
# Processing Files (4 / 7)      :  43% 227M/523M [00:01<00:02, 147MB/s,  149MB/s  ]
#
#   ...hunk-000/file-000.parquet: 100% 90.1k/90.1k [00:01<?, ?B/s]
#
#
#   ...hunk-000/file-000.parquet: 100% 1.41M/1.41M [00:01<?, ?B/s]
#
#
#
#   ...leanup/meta/tasks.parquet: 100% 2.27k/2.27k [00:01<?, ?B/s]
#
#
#
#
#   ...st/chunk-000/file-001.mp4: 100% 33.1M/33.1M [00:01<00:00, 11.4MB/s]
#
#
#
#
#
#   ...nt/chunk-000/file-000.mp4:  32% 67.1M/209M [00:01<00:04, 35.3MB/s]
#
#
#
#
#
#
#   ...st/chunk-000/file-000.mp4:  44% 92.3M/208M [00:01<00:01, 59.0MB/s]
#
#
#
#
#
#
#
# Processing Files (4 / 7)      :  50% 261M/523M [00:01<00:01, 154MB/s,  152MB/s  ]
#
#   ...hunk-000/file-000.parquet: 100% 90.1k/90.1k [00:01<?, ?B/s]
#
#
#   ...hunk-000/file-000.parquet: 100% 1.41M/1.41M [00:01<?, ?B/s]
#
#
#
#   ...leanup/meta/tasks.parquet: 100% 2.27k/2.27k [00:01<?, ?B/s]
#
#
#
#
#   ...st/chunk-000/file-001.mp4: 100% 33.1M/33.1M [00:01<00:00, 10.0MB/s]
#
#
#
#
#
#   ...nt/chunk-000/file-000.mp4:  36% 75.5M/209M [00:01<00:03, 36.1MB/s]
#
#
#
#
#
#
#   ...st/chunk-000/file-000.mp4:  48% 101M/208M [00:01<00:01, 56.8MB/s]
#
#
#
#
#
#
#
# Processing Files (5 / 7)      :  54% 282M/523M [00:02<00:01, 139MB/s,  146MB/s  ]
#
#   ...hunk-000/file-000.parquet: 100% 90.1k/90.1k [00:01<?, ?B/s]
#
#
#   ...hunk-000/file-000.parquet: 100% 1.41M/1.41M [00:01<?, ?B/s]
#
#
#
#   ...leanup/meta/tasks.parquet: 100% 2.27k/2.27k [00:01<?, ?B/s]
#
#
#
#
#   ...st/chunk-000/file-001.mp4: 100% 33.1M/33.1M [00:01<00:00, 8.92MB/s]
#
#
#
#
#
#   ...nt/chunk-000/file-000.mp4:  44% 92.2M/209M [00:01<00:02, 41.3MB/s]
#
#
#
#
#
#
#   ...st/chunk-000/file-000.mp4:  52% 109M/208M [00:01<00:01, 55.1MB/s]
#
#
#
#
#
#
#
# Processing Files (5 / 7)      :  59% 307M/523M [00:02<00:01, 135MB/s,  144MB/s  ]
#
#   ...hunk-000/file-000.parquet: 100% 90.1k/90.1k [00:02<?, ?B/s]
#
#
#   ...hunk-000/file-000.parquet: 100% 1.41M/1.41M [00:02<?, ?B/s]
#
#
#
#   ...leanup/meta/tasks.parquet: 100% 2.27k/2.27k [00:02<?, ?B/s]
#
#
#
#
#   ...st/chunk-000/file-001.mp4: 100% 33.1M/33.1M [00:02<00:00, 8.05MB/s]
#
#
#
#
#
#   ...nt/chunk-000/file-000.mp4:  52% 109M/209M [00:02<00:02, 45.6MB/s]
#
#
#
#
#
#
#   ...st/chunk-000/file-000.mp4:  61% 126M/208M [00:02<00:01, 58.1MB/s]
#
#
#
#
#
#
#
# Processing Files (5 / 7)      :  65% 341M/523M [00:02<00:01, 145MB/s,  147MB/s  ]
#
#   ...hunk-000/file-000.parquet: 100% 90.1k/90.1k [00:02<?, ?B/s]
#
#
#   ...hunk-000/file-000.parquet: 100% 1.41M/1.41M [00:02<?, ?B/s]
#
#
#
#   ...leanup/meta/tasks.parquet: 100% 2.27k/2.27k [00:02<?, ?B/s]
#
#
#
#
#   ...st/chunk-000/file-001.mp4: 100% 33.1M/33.1M [00:02<00:00, 7.32MB/s]
#
#
#
#
#
#   ...nt/chunk-000/file-000.mp4:  60% 126M/209M [00:02<00:01, 49.0MB/s]
#
#
#
#
#
#
#   ...st/chunk-000/file-000.mp4:  69% 143M/208M [00:02<00:01, 60.4MB/s]
#
#
#
#
#
#
#
# Processing Files (5 / 7)      :  72% 375M/523M [00:02<00:00, 152MB/s,  148MB/s  ]
#
#   ...hunk-000/file-000.parquet: 100% 90.1k/90.1k [00:02<?, ?B/s]
#
#
#   ...hunk-000/file-000.parquet: 100% 1.41M/1.41M [00:02<?, ?B/s]
#
#
#
#   ...leanup/meta/tasks.parquet: 100% 2.27k/2.27k [00:02<?, ?B/s]
#
#
#
#
#   ...st/chunk-000/file-001.mp4: 100% 33.1M/33.1M [00:02<00:00, 6.72MB/s]
#
#
#
#
#
#   ...nt/chunk-000/file-000.mp4:  68% 143M/209M [00:02<00:01, 51.9MB/s]
#
#
#
#
#
#
#   ...st/chunk-000/file-000.mp4:  77% 159M/208M [00:02<00:00, 62.3MB/s]
#
#
#
#
#
#
#
# Processing Files (5 / 7)      :  78% 408M/523M [00:02<00:00, 157MB/s,  150MB/s  ]
#
#   ...hunk-000/file-000.parquet: 100% 90.1k/90.1k [00:02<?, ?B/s]
#
#
#   ...hunk-000/file-000.parquet: 100% 1.41M/1.41M [00:02<?, ?B/s]
#
#
#
#   ...leanup/meta/tasks.parquet: 100% 2.27k/2.27k [00:02<?, ?B/s]
#
#
#
#
#   ...st/chunk-000/file-001.mp4: 100% 33.1M/33.1M [00:02<00:00, 6.20MB/s]
#
#
#
#
#
#   ...nt/chunk-000/file-000.mp4:  72% 151M/209M [00:02<00:01, 51.1MB/s]
#
#
#
#
#
#
#   ...st/chunk-000/file-000.mp4:  85% 176M/208M [00:02<00:00, 63.9MB/s]
#
#
#
#
#
#
#
# Processing Files (5 / 7)      :  83% 433M/523M [00:03<00:00, 147MB/s,  148MB/s  ]
#
#   ...hunk-000/file-000.parquet: 100% 90.1k/90.1k [00:02<?, ?B/s]
#
#
#   ...hunk-000/file-000.parquet: 100% 1.41M/1.41M [00:02<?, ?B/s]
#
#
#
#   ...leanup/meta/tasks.parquet: 100% 2.27k/2.27k [00:02<?, ?B/s]
#
#
#
#
#   ...st/chunk-000/file-001.mp4: 100% 33.1M/33.1M [00:02<00:00, 5.77MB/s]
#
#
#
#
#
#   ...nt/chunk-000/file-000.mp4:  80% 168M/209M [00:02<00:00, 53.5MB/s]
#
#
#
#
#
#
#   ...st/chunk-000/file-000.mp4:  89% 185M/208M [00:02<00:00, 62.4MB/s]
#
#
#
#
#
#
#
# Processing Files (5 / 7)      :  88% 458M/523M [00:03<00:00, 141MB/s,  147MB/s  ]
#
#   ...hunk-000/file-000.parquet: 100% 90.1k/90.1k [00:03<?, ?B/s]
#
#
#   ...hunk-000/file-000.parquet: 100% 1.41M/1.41M [00:03<?, ?B/s]
#
#
#
#   ...leanup/meta/tasks.parquet: 100% 2.27k/2.27k [00:03<?, ?B/s]
#
#
#
#
#   ...st/chunk-000/file-001.mp4: 100% 33.1M/33.1M [00:03<00:00, 5.38MB/s]
#
#
#
#
#
#   ...nt/chunk-000/file-000.mp4:  88% 184M/209M [00:03<00:00, 55.4MB/s]
#
#
#
#
#
#
#   ...st/chunk-000/file-000.mp4:  97% 201M/208M [00:03<00:00, 63.8MB/s]
#
#
#
#
#
#
#
# Processing Files (5 / 7)      :  94% 492M/523M [00:03<00:00, 148MB/s,  148MB/s  ]
#
#   ...hunk-000/file-000.parquet: 100% 90.1k/90.1k [00:03<?, ?B/s]
#
#
#   ...hunk-000/file-000.parquet: 100% 1.41M/1.41M [00:03<?, ?B/s]
#
#
#
#   ...leanup/meta/tasks.parquet: 100% 2.27k/2.27k [00:03<?, ?B/s]
#
#
#
#
#   ...st/chunk-000/file-001.mp4: 100% 33.1M/33.1M [00:03<00:00, 5.05MB/s]
#
#
#
#
#
#   ...nt/chunk-000/file-000.mp4:  96% 201M/209M [00:03<00:00, 57.2MB/s]
#
#
#
#
#
#
#   ...st/chunk-000/file-000.mp4: 100% 208M/208M [00:03<00:00, 61.9MB/s]
#
#
#
#
#
#
#
# Processing Files (6 / 7)      :  98% 515M/523M [00:03<00:00, 139MB/s,  146MB/s  ]
#
#   ...hunk-000/file-000.parquet: 100% 90.1k/90.1k [00:03<?, ?B/s]
#
#
#   ...hunk-000/file-000.parquet: 100% 1.41M/1.41M [00:03<?, ?B/s]
#
#
#
#   ...leanup/meta/tasks.parquet: 100% 2.27k/2.27k [00:03<?, ?B/s]
#
#
#
#
#   ...st/chunk-000/file-001.mp4: 100% 33.1M/33.1M [00:03<00:00, 4.76MB/s]
#
#
#
#
#
#   ...nt/chunk-000/file-000.mp4: 100% 209M/209M [00:03<00:00, 56.2MB/s]
#
#
#
#
#
#
#   ...st/chunk-000/file-000.mp4: 100% 208M/208M [00:03<00:00, 58.2MB/s]
#
#
#
#
#
#
#
# Processing Files (7 / 7)      : 100% 523M/523M [00:03<00:00, 109MB/s,  140MB/s  ]
#
#   ...hunk-000/file-000.parquet: 100% 90.1k/90.1k [00:03<?, ?B/s]
#
#
#   ...hunk-000/file-000.parquet: 100% 1.41M/1.41M [00:03<?, ?B/s]
#
#
#
#   ...leanup/meta/tasks.parquet: 100% 2.27k/2.27k [00:03<?, ?B/s]
#
#
#
#
#   ...st/chunk-000/file-001.mp4: 100% 33.1M/33.1M [00:03<00:00, 4.50MB/s]
#
#
#
#
#
#   ...nt/chunk-000/file-000.mp4: 100% 209M/209M [00:03<00:00, 53.1MB/s]
#
#
#
#
#
#
#   ...st/chunk-000/file-000.mp4: 100% 208M/208M [00:03<00:00, 55.0MB/s]
#
#
#
#
#
#
#
#   ...nt/chunk-000/file-001.mp4: 100% 71.6M/71.6M [00:03<00:00, 17.6MB/s]
#
#   ...hunk-000/file-000.parquet: 100% 90.1k/90.1k [00:03<?, ?B/s]
#
#
#   ...hunk-000/file-000.parquet: 100% 1.41M/1.41M [00:03<?, ?B/s]
#
#
#
#   ...leanup/meta/tasks.parquet: 100% 2.27k/2.27k [00:03<?, ?B/s]
#
#
#
#
#   ...st/chunk-000/file-001.mp4: 100% 33.1M/33.1M [00:03<00:00, 4.34MB/s]
#
#
#
#
#
#   ...nt/chunk-000/file-000.mp4: 100% 209M/209M [00:03<00:00, 51.2MB/s]
#
#
#
#
#
#
#   ...st/chunk-000/file-000.mp4: 100% 208M/208M [00:03<00:00, 53.1MB/s]
#
#
#
#
#
#
#
#   ...nt/chunk-000/file-001.mp4: 100% 71.6M/71.6M [00:03<00:00, 17.0MB/s]
#
#   ...hunk-000/file-000.parquet: 100% 90.1k/90.1k [00:03<?, ?B/s]
#
#
#   ...hunk-000/file-000.parquet: 100% 1.41M/1.41M [00:03<?, ?B/s]
#
#
#
#   ...leanup/meta/tasks.parquet: 100% 2.27k/2.27k [00:03<?, ?B/s]
#
#
#
#
#   ...st/chunk-000/file-001.mp4: 100% 33.1M/33.1M [00:03<00:00, 4.26MB/s]
#
#
#
#
#
#   ...nt/chunk-000/file-000.mp4: 100% 209M/209M [00:03<00:00, 50.3MB/s]
#
#
#
#
#
#
#   ...st/chunk-000/file-000.mp4: 100% 208M/208M [00:03<00:00, 52.1MB/s]
#
#
#
#
#
#
#
# Processing Files (7 / 7)      : 100% 523M/523M [00:04<00:00, 124MB/s,  125MB/s  ]
# New Data Upload               : |          |  0.00B /  0.00B,  0.00B/s
#   ...hunk-000/file-000.parquet: 100% 90.1k/90.1k [00:03<?, ?B/s]
#   ...hunk-000/file-000.parquet: 100% 1.41M/1.41M [00:03<?, ?B/s]
#   ...leanup/meta/tasks.parquet: 100% 2.27k/2.27k [00:03<?, ?B/s]
#   ...st/chunk-000/file-001.mp4: 100% 33.1M/33.1M [00:03<00:00, 4.26MB/s]
#   ...nt/chunk-000/file-000.mp4: 100% 209M/209M [00:03<00:00, 50.3MB/s]
#   ...st/chunk-000/file-000.mp4: 100% 208M/208M [00:03<00:00, 52.1MB/s]
#   ...nt/chunk-000/file-001.mp4: 100% 71.6M/71.6M [00:03<00:00, 16.6MB/s]
# https://huggingface.co/datasets/dillondesilva/so101-table-cleanup/tree/v3.0/.

# %%
# Step 4: Verify the conversion from your repo
from lerobot.datasets.lerobot_dataset import LeRobotDataset

# Load the converted dataset from your repo to verify
# Note: download_videos=True forces download from HuggingFace Hub
# instead of relying on local cache
your_repo_id = "dillondesilva/so101-table-cleanup"
dataset = LeRobotDataset(
    repo_id=your_repo_id,
    force_cache_sync=True
)

print(f"Dataset loaded successfully from {your_repo_id}!")
print(f"Dataset metadata: {dataset.meta}")
# Out:
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# Fetching 10 files:   0%|          | 0/10 [00:00<?, ?it/s]
# Dataset loaded successfully from dillondesilva/so101-table-cleanup!
# Dataset Metadata: LeRobotDatasetMetadata({
#     Repository ID: 'dillondesilva/so101-table-cleanup',
#     Total episodes: '80',
#     Total frames: '47513',
#     Features: '['action', 'observation.state', 'observation.images.front', 'observation.images.wrist', 'timestamp', 'frame_index', 'episode_index', 'index', 'task_index']',
# })',
